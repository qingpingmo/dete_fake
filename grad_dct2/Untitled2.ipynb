# %%
run /opt/data/private/wangjuntong/code/dark_matter/galaximview-master/galaximview/launchviewer.py
# Out:
# isnapmin, isnapmax =  0 3

# %%
import galaximview
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import galaximview
#
# ModuleNotFoundError: No module named 'galaximview'

# %%
import sys

# 将galaximview库的路径添加到Python搜索路径中
sys.path.append('/opt/data/private/wangjuntong/code/dark_matter/galaximview-master')

# %%
import galaximview
